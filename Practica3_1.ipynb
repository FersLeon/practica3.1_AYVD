# %% [markdown]
# <a href="https://colab.research.google.com/github/FersLeon/practica3.1_AYVD/blob/main/Practica3_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
from scipy.stats import zscore
import seaborn as sns ##

# %%
#Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Archivo
data = pd.read_csv('/content/drive/MyDrive/Praticas/Aquifer_Petrignano.csv')
data.head(5)
# Out:
#          Date  Rainfall_Bastia_Umbra  Depth_to_Groundwater_P24  \
# 0  14/03/2006                    NaN                    -22.48
# 1  15/03/2006                    NaN                    -22.38
# 2  16/03/2006                    NaN                    -22.25
# 3  17/03/2006                    NaN                    -22.38
# 4  18/03/2006                    NaN                    -22.60
#
#    Depth_to_Groundwater_P25  Temperature_Bastia_Umbra  Temperature_Petrignano  \
# 0                    -22.18                       NaN                     NaN
# 1                    -22.14                       NaN                     NaN
# 2                    -22.04                       NaN                     NaN
# 3                    -22.04                       NaN                     NaN
# 4                    -22.04                       NaN                     NaN
#
#    Volume_C10_Petrignano  Hydrometry_Fiume_Chiascio_Petrignano
# 0                    NaN                                   NaN
# 1                    NaN                                   NaN
# 2                    NaN                                   NaN
# 3                    NaN                                   NaN
# 4                    NaN                                   NaN

# %% [markdown]
# Visualización de los datos.

# %%
# %matplotlib inline
plt.style.use('seaborn-whitegrid')
data.plot.line(x='Date',y='Rainfall_Bastia_Umbra')
plt.ylabel("Rainfall_Bastia_Umbra")
plt.title("Rainfall_Bastia_Umbra")
# Out:
# <ipython-input-4-f00547e2e4b8>:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')
# Text(0.5, 1.0, 'Rainfall_Bastia_Umbra')

# %%
# %matplotlib inline
plt.style.use('seaborn-whitegrid')
data.plot.line(x='Date',y='Depth_to_Groundwater_P24')
plt.ylabel("Depth_to_Groundwater_P24")
plt.title("Con Depth_to_Groundwater_P24")
# Out:
# <ipython-input-5-b97e05f67e4b>:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')
# Text(0.5, 1.0, 'Con Depth_to_Groundwater_P24')

# %%
# %matplotlib inline
plt.style.use('seaborn-whitegrid')
data.plot.line(x='Date',y='Temperature_Bastia_Umbra')
plt.ylabel("Temperature_Bastia_Umbra")
plt.title("Con Temperature_Bastia_Umbra")
# Out:
# <ipython-input-6-4bbd242c825b>:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')
# Text(0.5, 1.0, 'Con Temperature_Bastia_Umbra')

# %%
# %matplotlib inline
plt.style.use('seaborn-whitegrid')
data.plot.line(x='Date',y='Temperature_Petrignano')
plt.ylabel("Temperature_Petrignano")
plt.title("Con Temperature_Petrignano")
# Out:
# <ipython-input-7-d12e2105f705>:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')
# Text(0.5, 1.0, 'Con Temperature_Petrignano')

# %%
# %matplotlib inline
plt.style.use('seaborn-whitegrid')
data.plot.line(x='Date',y='Volume_C10_Petrignano')
plt.ylabel("Volume_C10_Petrignano")
plt.title("Con Volume_C10_Petrignano")
# Out:
# <ipython-input-8-58a8629acf4b>:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')
# Text(0.5, 1.0, 'Con Volume_C10_Petrignano')

# %%
# %matplotlib inline
plt.style.use('seaborn-whitegrid')
data.plot.line(x='Date',y='Hydrometry_Fiume_Chiascio_Petrignano')
plt.ylabel("Hydrometry_Fiume_Chiascio_Petrignano")
plt.title("Con Hydrometry_Fiume_Chiascio_Petrignano")
# Out:
# <ipython-input-9-68dfebc27937>:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')
# Text(0.5, 1.0, 'Con Hydrometry_Fiume_Chiascio_Petrignano')
